# %%
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk("rice_leaf_project"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
class_names=["bacterial leaf blight", "brown spot", "leaf smut"]
class_names
# Out:
# ['bacterial leaf blight', 'brown spot', 'leaf smut']

# %%
# !unzip "drive/MyDrive/rice_Leaf_test_folder/PRCP-1001-RiceLeaf_project.zip" -d "drive/MyDrive/rice_Leaf_test_folder"
# Out:
# Archive:  drive/MyDrive/rice_Leaf_test_folder/PRCP-1001-RiceLeaf_project.zip
#   inflating: drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut-20200814T055530Z-001.zip
#   inflating: drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot-20200814T055208Z-001.zip
#   inflating: drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight-20200814T055237Z-001.zip

# %%
# !unzip "drive/MyDrive/Rice_leaf_train_folder/PRCP-1001-RiceLeaf_project.zip" -d "drive/MyDrive/Rice_leaf_train_folder"
# Out:
# Archive:  drive/MyDrive/Rice_leaf_train_folder/PRCP-1001-RiceLeaf_project.zip
#   inflating: drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut-20200814T055530Z-001.zip
#   inflating: drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot-20200814T055208Z-001.zip
#   inflating: drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight-20200814T055237Z-001.zip

# %%
import time
import os
from os.path import exists

def count(dir, counter=0):
    "returns number of files in dir and subdirs"
    for pack in os.walk(dir):
        for f in pack[2]:
            counter += 1
    return dir + " : " + str(counter) + "files"

# %%
test_dir="/content/drive/MyDrive/rice_Leaf_test_folder"
train_dir="/content/drive/MyDrive/Rice_leaf_train_folder"

# %%
print('total images for training :', count(train_dir))
print('total images for test :', count(test_dir))
# Out:
# total images for training : /content/drive/MyDrive/Rice_leaf_train_folder : 123files
# total images for test : /content/drive/MyDrive/rice_Leaf_test_folder : 123files

# %%
class_names=["bacterial leaf blight", "brown spot", "leaf smut"]
class_names
# Out:
# ['bacterial leaf blight', 'brown spot', 'leaf smut']

# %%
print(len(class_names))
# Out:
# 3

# %%
# !unzip "/content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight-20200814T055237Z-001.zip" -d "/content/drive/MyDrive/Rice_leaf_train_folder/Data"
# Out:
# Archive:  /content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight-20200814T055237Z-001.zip
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight/DSC_0406.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight/DSC_0405.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight/DSC_0404.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight/DSC_0403.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight/DSC_0402.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight/DSC_0401.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight/DSC_0400.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight/DSC_0399.JPG
# ...

# %%
# !unzip "/content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot-20200814T055208Z-001.zip" -d "/content/drive/MyDrive/Rice_leaf_train_folder/Data"
# Out:
# Archive:  /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot-20200814T055208Z-001.zip
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot/DSC_0394.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot/DSC_0324.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot/DSC_0391.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot/DSC_0109.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot/DSC_0119.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot/DSC_0116.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot/DSC_0115.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot/DSC_0117.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot/DSC_0118.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot/DSC_0114.jpg
# ...

# %%
# !unzip "/content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut-20200814T055530Z-001.zip" -d "/content/drive/MyDrive/Rice_leaf_train_folder/Data"
# Out:
# Archive:  /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut-20200814T055530Z-001.zip
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut/DSC_0313.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut/DSC_0510.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut/DSC_0503.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut/DSC_0318.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut/DSC_0501.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut/DSC_0312.JPG
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut/DSC_0339.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut/DSC_0504.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut/DSC_0500.jpg
#   inflating: /content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut/DSC_0514.jpg
# ...

# %%
# !unzip "/content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight-20200814T055237Z-001.zip" -d "/content/drive/MyDrive/rice_Leaf_test_folder/Data"
# Out:
# Archive:  /content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight-20200814T055237Z-001.zip
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight/DSC_0406.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight/DSC_0405.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight/DSC_0404.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight/DSC_0403.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight/DSC_0402.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight/DSC_0401.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight/DSC_0400.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight/DSC_0399.JPG
# ...

# %%
# !unzip "/content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot-20200814T055208Z-001.zip" -d "/content/drive/MyDrive/rice_Leaf_test_folder/Data"
# Out:
# Archive:  /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot-20200814T055208Z-001.zip
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot/DSC_0394.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot/DSC_0324.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot/DSC_0391.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot/DSC_0109.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot/DSC_0119.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot/DSC_0116.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot/DSC_0115.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot/DSC_0117.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot/DSC_0118.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot/DSC_0114.jpg
# ...

# %%
# !unzip "/content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut-20200814T055530Z-001.zip" -d "/content/drive/MyDrive/rice_Leaf_test_folder/Data"
# Out:
# Archive:  /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut-20200814T055530Z-001.zip
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut/DSC_0313.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut/DSC_0510.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut/DSC_0503.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut/DSC_0318.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut/DSC_0501.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut/DSC_0312.JPG
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut/DSC_0339.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut/DSC_0504.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut/DSC_0500.jpg
#   inflating: /content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut/DSC_0514.jpg
# ...

# %%
filenames=["/content/drive/MyDrive/Rice_leaf_train_folder/Data" + fname + ".jpg" for fname in class_names]
filenames
# Out:
# ['/content/drive/MyDrive/Rice_leaf_train_folder/Databacterial leaf blight.jpg',
#  '/content/drive/MyDrive/Rice_leaf_train_folder/Databrown spot.jpg',
#  '/content/drive/MyDrive/Rice_leaf_train_folder/Dataleaf smut.jpg']

# %% [markdown]
# # visualizing images

# %%
from IPython.display import Image
Image("/content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight/DSC_0379.JPG")

# %%
# !ls -la "/content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight"
# Out:
# total 17325
# -rw------- 1 root root 467109 Jan 27  2016 DSC_0365.JPG
# -rw------- 1 root root 417929 Feb  7  2016 DSC_0366.jpg
# -rw------- 1 root root 452625 Feb 13  2019 DSC_0367.JPG
# -rw------- 1 root root 428732 Feb  7  2016 DSC_0370.jpg
# -rw------- 1 root root 481489 Feb 13  2019 DSC_0372.JPG
# -rw------- 1 root root 393761 Jan 27  2016 DSC_0373.JPG
# -rw------- 1 root root 497216 Jan 27  2016 DSC_0374.JPG
# -rw------- 1 root root 417823 Jan 27  2016 DSC_0375.JPG
# -rw------- 1 root root 403699 Jan 27  2016 DSC_0376.JPG
# -rw------- 1 root root 388554 Jan 22  2016 DSC_0377.JPG
# -rw------- 1 root root 537232 Jan 22  2016 DSC_0378.JPG
# -rw------- 1 root root 432434 Jan 22  2016 DSC_0379.JPG
# -rw------- 1 root root 484552 Jan 27  2016 DSC_0380.JPG
# -rw------- 1 root root 440993 Feb 13  2019 DSC_0381.JPG
# -rw------- 1 root root 451417 Jan 27  2016 DSC_0382.JPG
# -rw------- 1 root root 527791 Jan 27  2016 DSC_0383.JPG
# -rw------- 1 root root 415585 Jan 27  2016 DSC_0384.JPG
# ...

# %%
# !ls -la "/content/drive/MyDrive/Rice_leaf_train_folder/Data"
# Out:
# total 36648
# drwx------ 2 root root     4096 Nov 21 11:37 'Bacterial leaf blight'
# -rw------- 1 root root 17738129 Aug 13  2020 'Bacterial leaf blight-20200814T055237Z-001.zip'
# drwx------ 2 root root     4096 Nov 21 11:38 'Brown spot'
# -rw------- 1 root root  9833233 Aug 13  2020 'Brown spot-20200814T055208Z-001.zip'
# drwx------ 2 root root     4096 Nov 21 11:38 'Leaf smut'
# -rw------- 1 root root  9942553 Aug 13  2020 'Leaf smut-20200814T055530Z-001.zip'

# %%
import os
# walk through pizza steak directory and list number offiles
for dirpath, dirnames, filenames in os.walk("drive/MyDrive/Rice_leaf_train_folder/Data/"):
  print(f"there are {len(dirnames)}directories and {len(filenames)} images in'{dirpath}'.")
# Out:
# there are 3directories and 3 images in'drive/MyDrive/Rice_leaf_train_folder/Data/'.
# there are 0directories and 40 images in'drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight'.
# there are 0directories and 40 images in'drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot'.
# there are 0directories and 39 images in'drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut'.

# %%
import os
# walk through pizza steak directory and list number offiles
for dirpath, dirnames, filenames in os.walk("drive/MyDrive/rice_Leaf_test_folder/Data"):
  print(f"there are {len(dirnames)}directories and {len(filenames)} images in'{dirpath}'.")
# Out:
# there are 3directories and 3 images in'drive/MyDrive/rice_Leaf_test_folder/Data'.
# there are 0directories and 40 images in'drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight'.
# there are 0directories and 40 images in'drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot'.
# there are 0directories and 39 images in'drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut'.

# %%
num_blight_images_train=len(os.listdir("/content/drive/MyDrive/Rice_leaf_train_folder/Data/Bacterial leaf blight"))
num_blight_images_train
# Out:
# 40

# %%
num_spot_images_train=len(os.listdir("/content/drive/MyDrive/Rice_leaf_train_folder/Data/Brown spot"))
num_spot_images_train
# Out:
# 40

# %%
num_smut_images_train=len(os.listdir("/content/drive/MyDrive/Rice_leaf_train_folder/Data/Leaf smut"))
num_smut_images_train
# Out:
# 39

# %%
num_smut_test_images=len(os.listdir("/content/drive/MyDrive/rice_Leaf_test_folder/Data/Leaf smut"))
num_smut_test_images
# Out:
# 39

# %%
num_brown_test_images=len(os.listdir("/content/drive/MyDrive/rice_Leaf_test_folder/Data/Brown spot"))
num_brown_test_images
# Out:
# 40

# %%
num_blight_test_images=len(os.listdir("/content/drive/MyDrive/rice_Leaf_test_folder/Data/Bacterial leaf blight"))
num_blight_test_images
# Out:
# 40

# %%
import pathlib
import numpy as np
data_dir=pathlib.Path("/content/drive/MyDrive/rice_Leaf_test_folder/Data")
class_names=np.array(sorted([item.name for item in data_dir.glob("*")]))
class_names=class_names[1:]
print(class_names)
# Out:
# ['Bacterial leaf blight-20200814T055237Z-001.zip' 'Brown spot'
#  'Brown spot-20200814T055208Z-001.zip' 'Leaf smut'
#  'Leaf smut-20200814T055530Z-001.zip']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# rescale 
train_datagen=ImageDataGenerator(rescale=1/255.)
test_datagen=ImageDataGenerator(rescale=1/255.)
IMG_SIZE=(224,224)
# data in from directories and turn it into batches
train_data=train_datagen.flow_from_directory(train_dir,
                                             target_size=(224,224),
                                             batch_size=32,
                                             class_mode="categorical")
test_data=test_datagen.flow_from_directory(test_dir,
                                           target_size=(224,224),
                                           batch_size=32,
                                           class_mode="categorical")
# Out:
# Found 119 images belonging to 1 classes.
# Found 119 images belonging to 1 classes.

# %%
print(f"training sample:\n {train_data[0]}\n")
print(f"training label:\n{class_names[0]}\n")
# Out:
# training sample:
#  (array([[[[0.9294118 , 0.8862746 , 0.87843144],
#          [0.9294118 , 0.8745099 , 0.8705883 ],
#          [0.9294118 , 0.8862746 , 0.87843144],
#          ...,
#          [0.9333334 , 0.89019614, 0.8745099 ],
#          [0.92549026, 0.882353  , 0.86666673],
#          [0.8980393 , 0.83921576, 0.85098046]],
#
#         [[0.9294118 , 0.8862746 , 0.87843144],
#          [0.9294118 , 0.8745099 , 0.8705883 ],
#          [0.92549026, 0.882353  , 0.8745099 ],
#          ...,
#          [0.9333334 , 0.89019614, 0.8745099 ],
#          [0.9333334 , 0.89019614, 0.8745099 ],
#          [0.9176471 , 0.86274517, 0.86274517]],
#
#         [[0.92549026, 0.882353  , 0.8745099 ],
#          [0.9333334 , 0.87843144, 0.8745099 ],
#          [0.93725497, 0.882353  , 0.87843144],
#          ...,
#          [0.9333334 , 0.8980393 , 0.87843144],
#          [0.9294118 , 0.8862746 , 0.8705883 ],
#          [0.9333334 , 0.87843144, 0.86666673]],
#
#         ...,
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf

# %%
flatten_model=tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28,28))])
flatten_model.output_shape
# Out:
# (None, 784)

# %%
import pathlib 
import numpy as np
data_dir=pathlib.Path("/content/drive/MyDrive/Rice_leaf_train_folder/Data")
class_names=np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_names)
# Out:
# ['Bacterial leaf blight' 'Bacterial leaf blight-20200814T055237Z-001.zip'
#  'Brown spot' 'Brown spot-20200814T055208Z-001.zip' 'Leaf smut'
#  'Leaf smut-20200814T055530Z-001.zip']

# %%
train_dir
# Out:
# '/content/drive/MyDrive/Rice_leaf_train_folder'

# %%
test_dir
# Out:
# '/content/drive/MyDrive/rice_Leaf_test_folder'

# %%
train_dir="/content/drive/MyDrive/Rice_leaf_train_folder/Data"
test_dir="/content/drive/MyDrive/rice_Leaf_test_folder/Data"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# rescale 
train_datagen=ImageDataGenerator(rescale=1/255.)
test_datagen=ImageDataGenerator(rescale=1/255.)
IMG_SIZE=(224,224)
# data in from directories and turn it into batches
train_data=train_datagen.flow_from_directory(train_dir,
                                             target_size=(224,224),
                                             batch_size=32,
                                             shuffle=True,
                                             class_mode="categorical",
                                             seed=42)
test_data=test_datagen.flow_from_directory(test_dir,
                                           target_size=(224,224),
                                           batch_size=32,
                                           shuffle=True,
                                           class_mode="categorical",
                                           seed=42)
# Out:
# Found 119 images belonging to 3 classes.
# Found 119 images belonging to 3 classes.

# %% [markdown]
# # model_1

# %%
tf.random.set_seed(42)
model_1=tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(28,28)),
  tf.keras.layers.Dense(3, activation="relu"),
  tf.keras.layers.Dense(3,activation="relu"),
  tf.keras.layers.Dense(3, activation="softmax")
])
# compile model
model_1.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                 optimizer=tf.keras.optimizers.SGD(),
                 metrics=["accuracy"])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D, Activation # create model 
model_1=Sequential([
  Conv2D(10,3, input_shape=(224,224,3)),
  Activation(activation="relu"),
  Conv2D(10,3,activation="relu"),
  MaxPool2D(),
  Conv2D(10,3, activation="relu"),
  Conv2D(10,3, activation="relu"),
  MaxPool2D(),
  Flatten(),
  Dense(3, activation="softmax") # output neurons
])
# compile model
model_1.compile(loss="categorical_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# %%
history_1=model_1.fit(train_data,
                      epochs=5,
                      steps_per_epoch=len(train_data),
                      validation_data=test_data,
                      validation_steps=len(test_data))
# Out:
# Epoch 1/5
# 4/4 [==============================] - 75s 13s/step - loss: 1.2850 - accuracy: 0.3529 - val_loss: 1.1680 - val_accuracy: 0.3361
# Epoch 2/5
# 4/4 [==============================] - 8s 2s/step - loss: 1.1494 - accuracy: 0.3529 - val_loss: 1.0900 - val_accuracy: 0.3277
# Epoch 3/5
# 4/4 [==============================] - 8s 2s/step - loss: 1.0890 - accuracy: 0.4034 - val_loss: 1.0738 - val_accuracy: 0.3613
# Epoch 4/5
# 4/4 [==============================] - 8s 2s/step - loss: 1.0720 - accuracy: 0.3613 - val_loss: 1.0541 - val_accuracy: 0.4034
# Epoch 5/5
# 4/4 [==============================] - 8s 2s/step - loss: 1.0425 - accuracy: 0.4454 - val_loss: 1.0208 - val_accuracy: 0.5966

# %%
len(train_data)
# Out:
# 4

# %%
model_1.evaluate(test_data)
# Out:
# 4/4 [==============================] - 4s 905ms/step - loss: 1.0208 - accuracy: 0.5966
# [1.020846962928772, 0.5966386795043945]

# %% [markdown]
# # loss curves

# %%
def plot_loss_curves(history):
  loss=history.history["loss"]
  val_loss=history.history["val_loss"]
  accuracy=history.history["accuracy"]
  val_accuracy=history.history["val_accuracy"]
  epochs=range(len(history.history["loss"])) # how many epochs did run 
  # plot loss
  plt.plot(epochs,loss, label="training_loss")
  plt.plot(epochs,val_loss, label="val_loss")
  plt.title("loss")
  plt.xlabel("epochs")
  plt.legend()
  # plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label="training_accuracy")
  plt.plot(epochs, val_accuracy, label="val_accuracy")
  plt.title("accuracy")
  plt.xlabel("epochs")
  plt.legend()

# %%
plot_loss_curves(history_1)

# %% [markdown]
# # model_2

# %%
model_2=Sequential([
  Conv2D(10,3,activation="relu", input_shape=(224,224,3)),
  MaxPool2D(),
  Conv2D(10,3,activation="relu"),
  MaxPool2D(),
  Flatten(),
  Dense(3, activation="softmax")
])
# compile model
model_2.compile(loss="categorical_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# %%
history_2=model_2.fit(train_data,
                      epochs=5,
                      steps_per_epoch=len(train_data),
                      validation_data=test_data,
                      validation_steps=len(test_data))
# Out:
# Epoch 1/5
# 4/4 [==============================] - 9s 3s/step - loss: 4.0828 - accuracy: 0.2521 - val_loss: 2.9138 - val_accuracy: 0.3361
# Epoch 2/5
# 4/4 [==============================] - 8s 2s/step - loss: 3.0304 - accuracy: 0.3697 - val_loss: 2.4418 - val_accuracy: 0.3361
# Epoch 3/5
# 4/4 [==============================] - 7s 2s/step - loss: 1.7180 - accuracy: 0.3361 - val_loss: 1.0344 - val_accuracy: 0.4286
# Epoch 4/5
# 4/4 [==============================] - 7s 2s/step - loss: 1.1695 - accuracy: 0.3529 - val_loss: 1.0974 - val_accuracy: 0.3277
# Epoch 5/5
# 4/4 [==============================] - 7s 2s/step - loss: 1.0558 - accuracy: 0.3445 - val_loss: 0.9855 - val_accuracy: 0.5378

# %%
model_2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 222, 222, 10)      280
#
#  max_pooling2d_2 (MaxPooling  (None, 111, 111, 10)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 109, 109, 10)      910
#
#  max_pooling2d_3 (MaxPooling  (None, 54, 54, 10)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 29160)             0
#
#  dense_4 (Dense)             (None, 3)                 87483
#
# ...
# Total params: 88,673
# Trainable params: 88,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_loss_curves(history_2)

# %% [markdown]
# # data augmentation

# %%
# create data augmented data generator instance
train_datagen_augmented=ImageDataGenerator(rescale=1/255.,
                                           rotation_range=0.2,
                                           width_shift_range=0.2,
                                           height_shift_range=0.2,
                                           zoom_range=0.2,
                                           horizontal_flip=True)
train_data_augmented=train_datagen_augmented.flow_from_directory(train_dir,
                                                                 target_size=(224,224),
                                                                 batch_size=32,
                                                                 class_mode="categorical")
# Out:
# Found 119 images belonging to 3 classes.

# %% [markdown]
# # model_3

# %%
model_3=tf.keras.models.clone_model(model_2)
# compile clone model using same setup
model_3.compile(loss="categorical_crossentropy",
                 optimizer=tf.keras.optimizers.Adam(),
                 metrics=["accuracy"])

# %%
history_3=model_3.fit(train_data_augmented,
                        epochs=20,
                        steps_per_epoch=len(train_data_augmented),
                        validation_data=test_data,
                        validation_steps=len(test_data))
# Out:
# Epoch 1/20
# 4/4 [==============================] - 11s 3s/step - loss: 1.3771 - accuracy: 0.2605 - val_loss: 1.0452 - val_accuracy: 0.5630
# Epoch 2/20
# 4/4 [==============================] - 9s 3s/step - loss: 1.0764 - accuracy: 0.3950 - val_loss: 0.9809 - val_accuracy: 0.6723
# Epoch 3/20
# 4/4 [==============================] - 9s 3s/step - loss: 0.9608 - accuracy: 0.4874 - val_loss: 0.9370 - val_accuracy: 0.5210
# Epoch 4/20
# 4/4 [==============================] - 9s 3s/step - loss: 0.9203 - accuracy: 0.5882 - val_loss: 0.8697 - val_accuracy: 0.6975
# Epoch 5/20
# 4/4 [==============================] - 9s 2s/step - loss: 0.9095 - accuracy: 0.5714 - val_loss: 0.8643 - val_accuracy: 0.4958
# Epoch 6/20
# 4/4 [==============================] - 9s 2s/step - loss: 0.8615 - accuracy: 0.5798 - val_loss: 0.8480 - val_accuracy: 0.6387
# Epoch 7/20
# 4/4 [==============================] - 9s 2s/step - loss: 0.9075 - accuracy: 0.5882 - val_loss: 0.7887 - val_accuracy: 0.5714
# ...

# %%
model_3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 222, 222, 10)      280
#
#  max_pooling2d_2 (MaxPooling  (None, 111, 111, 10)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 109, 109, 10)      910
#
#  max_pooling2d_3 (MaxPooling  (None, 54, 54, 10)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 29160)             0
#
#  dense_4 (Dense)             (None, 3)                 87483
#
# ...
# Total params: 88,673
# Trainable params: 88,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_loss_curves(history_3)

# %% [markdown]
# # model_4 using model url

# %%
IMG_SIZE=224
INPUT_SHAPE=[None, IMG_SIZE, IMG_SIZE, 3] # btach, height, width, color channels
# setup output shape 
OUTPUT_SHAPE=len(class_names)
MODEL_URL= "https://tfhub.dev/google/imagenet/mobilenet_v2_130_224/classification/4"

# %%
import tensorflow_hub as hub

# %%
# create a function which builds a keras model
def create_model(input_shape=INPUT_SHAPE, output_shape=OUTPUT_SHAPE, model_url=MODEL_URL):
  print("building model with:" , MODEL_URL)
  # setup model layers
  model=tf.keras.Sequential([
    hub.KerasLayer(MODEL_URL), 
    tf.keras.layers.Dense(3,
                          activation="softmax")
    ])
  # compile model
  model.compile(
      loss=tf.keras.losses.CategoricalCrossentropy(),
      optimizer=tf.keras.optimizers.Adam(),
      metrics=["accuracy"]
  )
  # build model
  model.build(INPUT_SHAPE)
  return model

# %%
model=create_model()
model.summary()
# Out:
# building model with: https://tfhub.dev/google/imagenet/mobilenet_v2_130_224/classification/4
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer (KerasLayer)    (None, 1001)              5432713
#
#  dense_5 (Dense)             (None, 3)                 3006
#
# ...
# Total params: 5,435,719
# Trainable params: 3,006
# Non-trainable params: 5,432,713
# _________________________________________________________________

# %%
# %load_ext tensorboard

# %%
import datetime
#  create a function to build a tensorboard callback
def create_tensorboard_callback():
  # create a log directory fro storing tensorboard logs
  logdir=os.path.join("drive/MyDrive/dog breed identification/logs",
                      # make it so logs get tracked
                      datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
  return tf.keras.callbacks.TensorBoard(logdir)

# %%
early_stopping=tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",

# %%
NUM_IMAGES=1000 #@param {type:"slider", min:1000, max:10000,step:1000}

# %%
NUM_EPOCHS=20

# %%
# build function to train and return a trained model
def train_model():
  model_4=create_model()
  tensorboard=create_tensorboard_callback()
  model_4.fit(x=train_data,
            epochs=NUM_EPOCHS,
            validation_data=test_data,
            validation_freq=1,
            callbacks=[tensorboard, early_stopping])
  return model_4

# %%
model_4=train_model()
# Out:
# building model with: https://tfhub.dev/google/imagenet/mobilenet_v2_130_224/classification/4
# Epoch 1/20
# 4/4 [==============================] - 15s 3s/step - loss: 1.6331 - accuracy: 0.4034 - val_loss: 1.2292 - val_accuracy: 0.4454
# Epoch 2/20
# 4/4 [==============================] - 8s 2s/step - loss: 1.0572 - accuracy: 0.5126 - val_loss: 0.7394 - val_accuracy: 0.6555
# Epoch 3/20
# 4/4 [==============================] - 8s 2s/step - loss: 0.6507 - accuracy: 0.7311 - val_loss: 0.5177 - val_accuracy: 0.8067
# Epoch 4/20
# 4/4 [==============================] - 8s 2s/step - loss: 0.4680 - accuracy: 0.8235 - val_loss: 0.3915 - val_accuracy: 0.8403
# Epoch 5/20
# 4/4 [==============================] - 8s 2s/step - loss: 0.3517 - accuracy: 0.8487 - val_loss: 0.3043 - val_accuracy: 0.8571
# Epoch 6/20
# 4/4 [==============================] - 8s 2s/step - loss: 0.2777 - accuracy: 0.8824 - val_loss: 0.2429 - val_accuracy: 0.9244
# Epoch 7/20
# ...

# %%
test_data

# %%
predictions=model.predict(test_data, verbose=1)
predictions
# Out:
# 4/4 [==============================] - 4s 934ms/step
# array([[9.50120151e-01, 2.61855666e-02, 2.36942656e-02],
#        [9.80970144e-01, 1.42319752e-02, 4.79799695e-03],
#        [4.33151331e-03, 1.10103272e-01, 8.85565221e-01],
#        [9.76526558e-01, 2.56636948e-03, 2.09070556e-02],
#        [1.20641442e-03, 9.97492313e-01, 1.30126229e-03],
#        [9.74934816e-01, 6.10469002e-03, 1.89605858e-02],
#        [8.41943085e-01, 1.00734048e-01, 5.73228225e-02],
#        [3.80299650e-02, 9.57226634e-01, 4.74336743e-03],
#        [8.35101493e-03, 2.12887432e-02, 9.70360219e-01],
#        [9.71932769e-01, 1.13794142e-02, 1.66878030e-02],
#        [1.12242391e-02, 9.83284295e-01, 5.49144438e-03],
#        [1.85539916e-01, 8.27607363e-02, 7.31699347e-01],
#        [1.26995724e-02, 9.77524281e-01, 9.77612846e-03],
#        [2.49842764e-04, 9.98934329e-01, 8.15878855e-04],
#        [4.07270767e-04, 9.05164063e-01, 9.44287330e-02],
#        [9.95212078e-01, 4.51671379e-03, 2.71164143e-04],
# ...

# %%
predictions.shape
# Out:
# (119, 3)

# %%
index=0
print(predictions[index])
print(f"max value(probability of prediction):{np.max(predictions[index])}") # prediction probability also known as confidence intervals
print(f"sum:{np.sum(predictions[index])}")
print(f"max index:{np.argmax(predictions[index])}")
print(f"predictd label:{class_names[np.argmax(predictions[index])]}")
# Out:
# [0.95012015 0.02618557 0.02369427]
# max value(probability of prediction):0.9501201510429382
# sum:1.0
# max index:0
# predictd label:Bacterial leaf blight

# %%
np.sum(predictions[index])
# Out:
# 1.0

# %%
def get_pred_label(prediction_probabilities):
  """
  turns an array of prediction probabilities into labels
  """
  return class_names[np.argmax(prediction_probabilities)]
# get a predicted label badsed on an array of prediction probabilities
pred_label=get_pred_label(predictions[9])
pred_label
# Out:
# 'Bacterial leaf blight'

# %%
test_data

# %%
train_datagen_augmented=ImageDataGenerator(rescale=1/255.,
                                           rotation_range=0.2,
                                           width_shift_range=0.2,
                                           height_shift_range=0.2,
                                           zoom_range=0.2,
                                           horizontal_flip=True)
train_data_augmented=train_datagen_augmented.flow_from_directory(train_dir,
                                                                 target_size=(224,224),
                                                                 batch_size=32,
                                                                 class_mode="categorical")
# Out:
# Found 119 images belonging to 3 classes.

# %% [markdown]
# # model_5

# %%
model_5=tf.keras.models.clone_model(model_4)
# compile clone model using same setup
model_5.compile(loss="categorical_crossentropy",
                 optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                 metrics=["accuracy"])

# %%
history_5=model_5.fit(train_data_augmented,
                        epochs=20,
                        steps_per_epoch=len(train_data_augmented),
                        validation_data=test_data,
                        validation_steps=len(test_data))
# Out:
# Epoch 1/20
# 4/4 [==============================] - 10s 3s/step - loss: 0.1285 - accuracy: 0.9832 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 2/20
# 4/4 [==============================] - 9s 2s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9916
# Epoch 3/20
# 4/4 [==============================] - 9s 3s/step - loss: 0.0103 - accuracy: 0.9916 - val_loss: 0.0559 - val_accuracy: 0.9916
# Epoch 4/20
# 4/4 [==============================] - 9s 3s/step - loss: 0.0412 - accuracy: 0.9916 - val_loss: 0.0396 - val_accuracy: 0.9832
# Epoch 5/20
# 4/4 [==============================] - 9s 3s/step - loss: 0.0109 - accuracy: 0.9916 - val_loss: 0.0678 - val_accuracy: 0.9832
# Epoch 6/20
# 4/4 [==============================] - 9s 3s/step - loss: 0.0681 - accuracy: 0.9748 - val_loss: 0.0699 - val_accuracy: 0.9832
# Epoch 7/20
# 4/4 [==============================] - 9s 3s/step - loss: 0.0623 - accuracy: 0.9748 - val_loss: 0.0879 - val_accuracy: 0.9580
# ...

# %%
model_5.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer_3 (KerasLayer)  (None, 1001)              5432713
#
#  dense_15 (Dense)            (None, 3)                 3006
#
# ...
# Total params: 5,435,719
# Trainable params: 3,006
# Non-trainable params: 5,432,713
# _________________________________________________________________

# %%
plot_loss_curves(history_5)

# %% [markdown]
# # prediction probabilities

# %%
def plot_pred_conf(prediction_probabilities, labels, n=1):
  pred_prob, true_label=prediction_probabilities[n], labels[n]
  # get predicted label
  pred_label=get_pred_label(pred_prob)
  # find top 10 prediction confidence indexes
  top_10_pred_indexes=pred_prob.argsort()[-10:][::-1]
  # find top 10 prediction confidence values
  top_10_pred_values=pred_prob[top_10_pred_indexes]
  # find top 10 prediction labels
  top_10_pred_labels=class_names[top_10_pred_indexes]
  # setup plot
  top_plot=plt.bar(np.arange(len(top_10_pred_labels)),
                   top_10_pred_values,
                   color="grey")
  plt.xticks(np.arange(len(top_10_pred_labels)),
             labels=top_10_pred_labels,
             rotation="vertical")
  # change color of true labels
  if np.isin(true_label, top_10_pred_labels):
    top_plot[np.argmax(top_10_pred_labels==true_label)].set_color("green")
  else:
    pass

# %%
plot_pred_conf(prediction_probabilities=predictions,
               labels=class_names,
               n=2)

# %%
predictions[0][predictions[0].argsort()[-10:][::-1]]
# Out:
# array([0.95012015, 0.02618557, 0.02369427], dtype=float32)

# %%
predictions[0].max()
# Out:
# 0.95012015

# %% [markdown]
# # getting images from net to make predictions on models

# %%
# !wget https://apps.lucidcentral.org/ppp/images/entities/rice_brown_leaf_spot_427/cochliobolus.jpg
# !wget https://pnwhandbooks.org/sites/pnwhandbooks/files/plant/images/lawn-and-turf-stripe-smut/stripsmut1.jpg
# !wget https://guide.utcrops.com/wp-content/uploads/2016/07/septoria-brown-spot-coalescent-lesions.jpg
# !wget https://crop-protection-network.s3.amazonaws.com/articles/photos/Bacterial-leaf-blight.-Burrows.July-2010-2.jpg
# !wget https://crop-protection-network.s3.amazonaws.com/articles/photos/Bacterial-leaf-blight.-Burrows.July-2010-4.jpg
# !wget https://www.lsuagcenter.com/~/media/system/c/b/6/0/cb601010e5d2cdd4c300151cdde99312/leafsmut6.jpg
# !wget https://www.gtlawnservice.com/wp-content/uploads/2020/07/Smut-5.jpg
# !wget http://www.knowledgebank.irri.org/images/stories/brown-spot-4.jpg
# Out:
# --2021-11-22 11:06:32--  https://apps.lucidcentral.org/ppp/images/entities/rice_brown_leaf_spot_427/cochliobolus.jpg
# Resolving apps.lucidcentral.org (apps.lucidcentral.org)... 172.67.128.157, 104.21.2.26, 2606:4700:3030::ac43:809d, ...
# Connecting to apps.lucidcentral.org (apps.lucidcentral.org)|172.67.128.157|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127297 (124K) [image/jpeg]
# Saving to: ‘cochliobolus.jpg.13’
#
# cochliobolus.jpg.13 100%[===================>] 124.31K  --.-KB/s    in 0.02s
#
# 2021-11-22 11:06:33 (5.76 MB/s) - ‘cochliobolus.jpg.13’ saved [127297/127297]
#
# --2021-11-22 11:06:33--  https://pnwhandbooks.org/sites/pnwhandbooks/files/plant/images/lawn-and-turf-stripe-smut/stripsmut1.jpg
# Resolving pnwhandbooks.org (pnwhandbooks.org)... 35.83.115.171
# Connecting to pnwhandbooks.org (pnwhandbooks.org)|35.83.115.171|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3840488 (3.7M) [image/jpeg]
# ...

# %%
def load_and_pred_image(filename,img_shape=224):
  # read in image 
  img=tf.io.read_file(filename)
  # decode read file into tensor
  img=tf.image.decode_image(img)
  # resize image
  img=tf.image.resize(img,size=[img_shape, img_shape])
  # rescale image to between 0 and 1
  img=img/255.
  return img

# %%
def pred_and_plot(model, filename, class_names=class_names):
  # import target image and preprocess it
  img=load_and_pred_image(filename)
  # make a prediction
  pred=model.predict(tf.expand_dims(img, axis=0))
  # add in logic for multi class
  if len(pred[0])>1:
    pred_class=class_names[tf.argmax(pred[0])]
  else:
    pred_class=class_names[int(tf.round(pred[0]))]
  # plot image predicted class
  plt.imshow(img)
  plt.title(f"prediction:{pred_class}")
  plt.axis(False);

# %% [markdown]
# # predicting random images to check model performance

# %%
pred_and_plot(model=model_5,
              filename="cochliobolus.jpg",
              class_names=class_names)

# %%
pred_and_plot(model=model_5,
              filename="stripsmut1.jpg",
              class_names=class_names)

# %%
pred_and_plot(model=model_5,
              filename="septoria-brown-spot-coalescent-lesions.jpg",
              class_names=class_names)

# %%
pred_and_plot(model=model_5,
              filename="Bacterial-leaf-blight.-Burrows.July-2010-2.jpg",
              class_names=class_names)

# %%
pred_and_plot(model=model_5,
              filename="Bacterial-leaf-blight.-Burrows.July-2010-4.jpg",
              class_names=class_names)

# %%
pred_and_plot(model=model_5,
              filename="brown-spot-4.jpg",
              class_names=class_names)
